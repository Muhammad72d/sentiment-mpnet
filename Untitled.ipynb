# %%
#بسم الله الرحمن الرحيم
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from joblib import dump

# %%
data=pd.read_csv('survey lung cancer.csv')

# %%
print(data.columns)
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
data['LUNG_CANCER'].value_counts().plot(kind='bar')
plt.title("Count of Survival")
plt.xlabel("Survived")
plt.ylabel("Count")
plt.show()

# %%
le=LabelEncoder()

# %%
for i in data.columns:
    if not data[i].dtype == 'int' and not data[i].dtype == 'float':
        data[i]=le.fit_transform(data[i])

# %%
print(data[:5])
# Out:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0       1   69        1               2        2              1
# 1       1   74        2               1        1              1
# 2       0   59        1               1        1              2
# 3       1   63        2               2        2              1
# 4       0   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  LUNG_CANCER
# ...

# %%
y=data['LUNG_CANCER']
data.drop(columns='LUNG_CANCER')
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 2         0   59        1               1        1              2
# 3         1   63        2               2        2              1
# 4         0   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 304       0   56        1               1        1              2
# 305       1   70        2               1        1              1
# 306       1   58        2               1        1              1
# 307       1   67        2               1        2              1
# 308       1   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
xt,xs,yt,ys=train_test_split(data,y,test_size=0.15,random_state=40)

# %%
svc_model=SVC()

# %%
svc_model.fit(xt,yt)
# Out:
# SVC()

# %%
svc_pred=svc_model.predict(xs)

# %%
svc_error=mean_squared_error(ys,svc_pred)

# %%
print(svc_error)
# Out:
# 0.06382978723404255

# %%
knn_model=KNeighborsClassifier()

# %%
knn_model.fit(xt,yt)
# Out:
# KNeighborsClassifier()

# %%
knn_pred=knn_model.predict(xs)

# %%
knn_error=mean_squared_error(ys,knn_pred)

# %%
print(knn_error)
# Out:
# 0.0425531914893617

# %%
rf_model=RandomForestClassifier()

# %%
rf_model.fit(xt,yt)
# Out:
# RandomForestClassifier()

# %%
rf_pred=rf_model.predict(xs)
rf_error=mean_squared_error(ys,rf_pred)
print(rf_error)
# Out:
# 0.0

# %%
dt_model=DecisionTreeClassifier()

# %%
dt_model.fit(xt,yt)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred=dt_model.predict(xs)

# %%
dt_error=mean_squared_error(ys,dt_pred)

# %%
print(dt_error)
# Out:
# 0.0

# %%
dump(knn_model,'lung cancer model.py')
# Out:
# ['lung cancer model.py']
