# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer
from keras.callbacks import EarlyStopping

# %%
import os
print(os.listdir())
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# Out:
# ['.config', '.ipynb_checkpoints', 'training.1600000.processed.noemoticon.csv', 'sample_data']

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Input,BatchNormalization
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam

# %%
df=pd.read_csv('training.1600000.processed.noemoticon.csv',encoding='latin-1')

# %%
df.columns=['target','id','x','y','z','txt']

# %%
sample=df.sample(n=100000)
sample=sample.drop(columns=['id','x','y','z'])

# %%
sample2=df.sample(n=100000)
sample2=sample2.drop(columns=['id','x','y','z'])

# %%
def clean(x):
  if not isinstance(x,str):
      return ''
  x=x.lower()
  x=re.sub(r'http\S+','',x)
  x=re.sub(r'@\w+','',x)
  x=re.sub(r'#','',x)
  x=re.sub(r'\s+',' ',x)
  x=re.sub(r'[^a-z\s\']','',x)
  x=re.sub(r'(.)\1,{2,}',r'\1\1',x)
  x=x.strip()
  return x

# %%
def minimize(x):
  if x<2:
   return 0
  else:
   return 1

# %%
sample['target']=sample['target'].apply(minimize)

# %%
sample2['target']=sample2['target'].apply(minimize)

# %%
plt.bar(sample['target'].value_counts().index,sample['target'].value_counts())
plt.show()

# %%
plt.bar(sample2['target'].value_counts().index,sample2['target'].value_counts())
plt.show()

# %%
sample['txt']=sample['txt'].apply(clean)
sample=sample[sample['txt']!='']
sample=sample.drop_duplicates(subset=['txt'])
sample=sample.dropna(subset=['txt'])

# %%
sample2['txt']=sample['txt'].apply(clean)
sample2=sample2[sample2['txt']!='']
sample2=sample2.drop_duplicates(subset=['txt'])
sample2=sample2.dropna(subset=['txt'])

# %%
print(sample['txt'].sample(10).tolist())
print(sample.shape)
# Out:
# ['plans for today  shower shopping rent some movies watch some movies eat tweet sleep', 'i had a twinky for the first time in years on friday i had so built then up in my mind that it was rather disappointing', 'back pain is just terribletake it from me nothing is helping the pain', 'thanks for the love i do give highfives on request and sometimes sporadically', "up can't fall back asleep tummy ache", 'anyone successfully deployed software to handsets via blackberry professional server index isnt finding anything', 'aww jade he sounds like a cutie', 'wants green tea latte with lots and lots of milk griltongue', 'the comic is such an ass poor sherman', 'hmmm sounds like it might be time to start']
# (97744, 2)

# %%
st=SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
txt=sample['txt'].tolist()

# %%
embeddings=st.encode(txt,
                     show_progress_bar=True,
                     batch_size=64)
# Out:
# Batches:   0%|          | 0/1528 [00:00<?, ?it/s]

# %%
embeddings2=st.encode(sample2['txt'].tolist(),
                     show_progress_bar=True,
                     batch_size=64)
# Out:
# Batches:   0%|          | 0/99 [00:00<?, ?it/s]

# %%
print(np.array(embeddings).shape)
# Out:
# (97744, 384)

# %%
xtrain,xtest,ytrain,ytest=train_test_split(embeddings,sample['target'],
                                           test_size=0.2,
                                           random_state=42)

# %%
xtrain2,xtest2,ytrain2,ytest2=train_test_split(embeddings2,
                                               sample2['target'],
                                               random_state=44,
                                               test_size=0.2)

# %%
Bert_model=Sequential([
    Input(shape=(xtrain.shape[1],)),
    Dense(512,activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(256,activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(128,activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(1,activation='sigmoid')])

# %%
lrn_rate=Adam(learning_rate=2e-5)

# %%
Bert_model.compile(optimizer=lrn_rate,
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

# %%
early=EarlyStopping(monitor='val_loss',
                    patience=2,
                    restore_best_weights=True)

# %%
history1=Bert_model.fit(xtrain,ytrain,
                       epochs=10,batch_size=32,
                       validation_split=0.1,
                       callbacks=[early],
                       verbose=1)
# Out:
# Epoch 1/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 28s 11ms/step - accuracy: 0.5936 - loss: 0.7723 - val_accuracy: 0.7332 - val_loss: 0.5370
# Epoch 2/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.6932 - loss: 0.6154 - val_accuracy: 0.7526 - val_loss: 0.5136
# Epoch 3/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 40s 9ms/step - accuracy: 0.7133 - loss: 0.5809 - val_accuracy: 0.7581 - val_loss: 0.5023
# Epoch 4/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 43s 10ms/step - accuracy: 0.7303 - loss: 0.5542 - val_accuracy: 0.7620 - val_loss: 0.4950
# Epoch 5/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.7347 - loss: 0.5423 - val_accuracy: 0.7668 - val_loss: 0.4899
# Epoch 6/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - accuracy: 0.7378 - loss: 0.5318 - val_accuracy: 0.7685 - val_loss: 0.4858
# Epoch 7/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - accuracy: 0.7484 - loss: 0.5191 - val_accuracy: 0.7716 - val_loss: 0.4831
# Epoch 8/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.7507 - loss: 0.5126 - val_accuracy: 0.7717 - val_loss: 0.4796
# Epoch 9/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - accuracy: 0.7573 - loss: 0.5023 - val_accuracy: 0.7744 - val_loss: 0.4783
# Epoch 10/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 39s 10ms/step - accuracy: 0.7580 - loss: 0.5014 - val_accuracy: 0.7739 - val_loss: 0.4761

# %%
history1=Bert_model.fit(xtrain2,ytrain2,
                       epochs=10,batch_size=32,
                       validation_split=0.1,
                       callbacks=[early],
                       verbose=1)
# Out:
# Epoch 1/10
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7580 - loss: 0.4945 - val_accuracy: 0.7945 - val_loss: 0.4288
# Epoch 2/10
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7678 - loss: 0.4863 - val_accuracy: 0.7925 - val_loss: 0.4293
# Epoch 3/10
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7677 - loss: 0.4922 - val_accuracy: 0.7945 - val_loss: 0.4292

# %%
plt.plot(history1.history['accuracy'],label='train')
plt.plot(history1.history['val_accuracy'],label='val accuracy')
plt.plot(history1.history['loss'],label='loss')
plt.plot(history1.history['val_loss'],label='val loss')
plt.legend()
plt.show()

# %%
temp=Bert_model.predict(xtest)
# Out:
# 611/611 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step

# %%
ypredict=(temp>=0.5).astype(int)

# %%
ac=accuracy_score(ytest,ypredict)
print(ac)
# Out:
# 0.7712926492403703
