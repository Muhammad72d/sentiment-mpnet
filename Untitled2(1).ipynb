# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer
from keras.callbacks import EarlyStopping

# %%
import os
print(os.listdir())
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# Out:
# ['.config', 'training.1600000.processed.noemoticon.csv', 'sample_data']

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Input,BatchNormalization
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam

# %%
df=pd.read_csv('training.1600000.processed.noemoticon.csv',encoding='latin-1')

# %%
df.columns=['target','id','x','y','z','txt']

# %%
sample=df.sample(n=100000)
sample=sample.drop(columns=['id','x','y','z'])

# %%
def clean(x):
  if not isinstance(x,str):
      return ''
  x=x.lower()
  x=re.sub(r'http\S+','',x)
  x=re.sub(r'@\w+','',x)
  x=re.sub(r'#','',x)
  x=re.sub(r'\s+',' ',x)
  x=re.sub(r'[^a-z\s\']','',x)
  x=re.sub(r'(.)\1,{2,}',r'\1\1',x)
  x=x.strip()
  return x

# %%
def minimize(x):
  if x<2:
   return 0
  else:
   return 1

# %%
sample['target']=sample['target'].apply(minimize)

# %%
plt.bar(sample['target'].value_counts().index,sample['target'].value_counts())
plt.show()

# %%
sample['txt']=sample['txt'].apply(clean)
sample=sample[sample['txt']!='']
sample=sample.drop_duplicates(subset=['txt'])
sample=sample.dropna(subset=['txt'])

# %%
print(sample['txt'].sample(10).tolist())
print(sample.shape)
# Out:
# ['i will you will be the st to know', "i hate when people make small talk on msn to fill the gaps please realise this isn't working i'm sorry i can't say it to your face", "it's too early to be awake and i got up   hours ago i should never wake up before", "what banana didn't win i vote a revote please", 'just took a great refreshing shower', 'yah im just gonna give up rite now no famous person is ever going to talk to me', "oh wow i have to work on sunday but i'm off on monday if you're still in town", 'my friend decided to not tell me anything andor ditch me so i am not there too', 'ah good  hear your apps are amongst the best in my book upgrades to android have only made you more of an original pioneer', 'making french fries']
# (97757, 2)

# %%
st=SentenceTransformer('all-mpnet-base-v2')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
txt=sample['txt'].tolist()

# %%
embeddings=st.encode(txt,
                     show_progress_bar=True,
                     batch_size=64)
# Out:
# Batches:   0%|          | 0/1528 [00:00<?, ?it/s]

# %%
print(np.array(embeddings).shape)
# Out:
# (97757, 768)

# %%
xtrain,xtest,ytrain,ytest=train_test_split(embeddings,sample['target'],
                                           test_size=0.2,
                                           random_state=42)

# %%
Bert_model=Sequential([
    Input(shape=(xtrain.shape[1],)),
    Dense(512,activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(256,activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(128,activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(1,activation='sigmoid')])

# %%
lrn_rate=Adam(learning_rate=2e-5)

# %%
Bert_model.compile(optimizer=lrn_rate,
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

# %%
early=EarlyStopping(monitor='val_loss',
                    patience=2,
                    restore_best_weights=True)

# %%
history1=Bert_model.fit(xtrain,ytrain,
                       epochs=10,batch_size=32,
                       validation_split=0.1,
                       callbacks=[early],
                       verbose=1)
# Out:
# Epoch 1/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.6396 - loss: 0.7136 - val_accuracy: 0.7705 - val_loss: 0.4899
# Epoch 2/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7366 - loss: 0.5615 - val_accuracy: 0.7851 - val_loss: 0.4709
# Epoch 3/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7541 - loss: 0.5292 - val_accuracy: 0.7863 - val_loss: 0.4611
# Epoch 4/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7601 - loss: 0.5074 - val_accuracy: 0.7888 - val_loss: 0.4538
# Epoch 5/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7675 - loss: 0.4923 - val_accuracy: 0.7908 - val_loss: 0.4491
# Epoch 6/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7712 - loss: 0.4851 - val_accuracy: 0.7927 - val_loss: 0.4449
# Epoch 7/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7753 - loss: 0.4772 - val_accuracy: 0.7940 - val_loss: 0.4425
# Epoch 8/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7805 - loss: 0.4664 - val_accuracy: 0.7952 - val_loss: 0.4409
# Epoch 9/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7818 - loss: 0.4641 - val_accuracy: 0.7954 - val_loss: 0.4379
# Epoch 10/10
# 2200/2200 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7891 - loss: 0.4553 - val_accuracy: 0.7950 - val_loss: 0.4359

# %%
plt.plot(history1.history['accuracy'],label='train')
plt.plot(history1.history['val_accuracy'],label='val accuracy')
plt.plot(history1.history['loss'],label='loss')
plt.plot(history1.history['val_loss'],label='val loss')
plt.legend()
plt.show()

# %%
temp=Bert_model.predict(xtest)
# Out:
# 611/611 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
ypredict=(temp>=0.5).astype(int)

# %%
ac=accuracy_score(ytest,ypredict)
print(ac)
# Out:
# 0.7974631751227496
